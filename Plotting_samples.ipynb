# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahesh6702/Research-Project/blob/main/Plotting_samples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mpld3

# %% [markdown]
# Visualising First 13class of forces

# %%
import pandas as pd 
from matplotlib import pyplot as plt
from google.colab import files
plt.style.use('seaborn-talk')
import io
import mpld3
from mpld3 import plugins

data = files.upload()
# Out:
#      <input type="file" id="files-016ea9fb-36eb-44c2-8d64-694b6d248a12" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-016ea9fb-36eb-44c2-8d64-694b6d248a12">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample1.csv to sample1.csv

# %% [markdown]
# Reading data from the file

# %%
data = pd.read_csv(io.StringIO(data['sample1.csv'].decode('utf-8')))

# %% [markdown]
# Assiging each colums in the file with name

# %%
Samples_values = data['Samples']
force_4N = data['Force4']
force_5N = data['Force5']
force_6N = data['Force6']
force_7N = data['Force7']
force_8N = data['Force8']
force_9N = data['Force9']
force_10N = data['Force10']
force_11N = data['Force11']
force_12N = data['Force12']
force_13N = data['Force13']
mpld3.display()

plt.plot(Samples_values, force_4N,'*',label ="4N Force")
plt.plot(Samples_values, force_5N,'*',label ="5N Force")
plt.plot(Samples_values, force_6N,'*',label ="6N Force")
plt.plot(Samples_values, force_7N,'*',label ="7N Force")
plt.plot(Samples_values, force_8N,'*',label ="8N Force")
plt.plot(Samples_values, force_9N,'*',label ="9N Force")
#plt.plot(Samples_values, force_10N,'*',label ="10N Force")
#plt.plot(Samples_values, force_11N,'*',label ="11N Force")
#plt.plot(Samples_values, force_12N,'*',label ="12N Force")
#plt.plot(Samples_values, force_13N,'*',label ="13N Force")
# mpld3.display()
plt.legend()
plt.title('Force class over no of samples')
plt.xlabel('No of Samples')
plt.ylabel('Resistance in Ω')
# Out:
# Text(0, 0.5, 'Resistance in Ω')
